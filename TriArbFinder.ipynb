# %% [markdown]
# # **Triangular Arbitrage Finder**
#
# **What is arbitrage?**
#
# Arbitrage is a discrepancy between the prices of two (or more) assets that allows making risk-free profit. For instance, if I was prepared to pay USD1 for an apple, and you know you can get one from the store for 50 cents, the rational thing for you to do is to purchase one from the store and sell it to me, and net 50 cents in the process. A similar logic applies on the stock market. For example, the stock A trades for USD100 on the NYSE while, at the same time, it trades for USD101 at the Shanghai Stock Exchange. You can buy the stock from the NYSE and immediately sells it on the Shanghai market, earning a profit of USD1
#
# Notice, however, that buying the stock will exert upward pressure on the stock’s price on NYSE, and similarly, selling will impose downward price pressure on Shanghai market. As a result of this dynamic, the spread in the stock’s prices on the two marketplaces will narrow down until arbitrage is unprofitable. Due to the vast number of investors scanning these exploitable price discrepancies on a sub-second scale, they are rare and short-lived in a liquid market such as the stock market, or the cryptocurrency market for that matter.
#
# **What is triangular arbitrage?**
#
# Triangular arbitrage is the result of a discrepancy between three assets - often currencies - that occurs when the currencies exchange rates do not exactly match up. This enables the trader to trade the first currency to the second, the second to third, and the third back to the first, so that she nets a small profit in the process. The following example may help understanding the idea:
#
# Let us assume you have $1 million, and you observe the following exchange rates on the market: USD/EUR = 0.8698; GBP/EUR = 1.3021; and GBP/USD = 1.5028. Can you make money through triangular arbitrage? Yes, you can, through the following operations.
#
# * Sell dollars for euros: USD1,000,000 x 0.8698 = EUR869,800
# * Sell euros for pounds: EUR869,800 / 1.3021 = GBP667,997.85
# * Sell pounds for dollars: GBP667,997.85 x 1.5028 = USD1,003,867.17
#
# You started with USD1 million, and ended up with USD1,003,867.17, implying the net profit was USD3,867.17, or roughly 0.39%. Notice, that it does not matter which of the three currencies is the "starting currency" held in beginning, as long as the trades are the same and come in same order in the loop.
#
# Now, you may think that a USD4k profit a abysmal considering you had USD1 million capital, but notice that you made it instantaneously, and thus, you can potentially make hundreds of such trades in a day. Indeed, making frequent trades with large capital in hopes of small profits is the essence of arbitrage trading.
#
# Now, it should go without saying that in practice, arbitrage of any kind is not the kind of money printing machine that the example above would you make you think. There many, many factors that make arbitrage trading *significantly* more challenging in practice than on paper. Among the main obstacles are fees and bid-ask spreads (though they are accounted for in my implementation), the sheer number of professional, highly optimized, lightning-fast algorithms competing for the same marginal profit, and rapid price fluctuations.
#
# **This project**
#
# This notebook contains a triangular arbitrage finder for the cryptocurrency market. It scans continuously the prices of all cryptocurrency pairs traded on Binance through a websocket, and reports back when it has identified a profitable triangular arbitrage opportunity with instructions about which currencies to trade and at which price. In other words, it automates the process of finding opportunities such as the example above.
#
# While it would be relatively straightforward to hook up a trading logic and portfolio management algorithm to the finder, this algorithm is not intended for actual trading purposes. First, Python is prohibitively slow for trading at sub-second scale. Second, being based on for loops, the algorithm itself is not optimized for speed. Third, one would want to specify on a handful of currencies which are tracked and traded; tracking thousands of assets adds unnecessary computational overhead.  Lastly, the algorithm does not take into account orderbook depth and prices at different depth levels.
#
# -----

# %% [markdown]
# **Install and import dependencies**

# %%
# %pip install ccxt
# %pip install websocket-client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: ccxt in /usr/local/lib/python3.7/dist-packages (1.93.66)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.7/dist-packages (from ccxt) (2022.6.15)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.7/dist-packages (from ccxt) (2.23.0)
# Requirement already satisfied: yarl==1.7.2 in /usr/local/lib/python3.7/dist-packages (from ccxt) (1.7.2)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.7/dist-packages (from ccxt) (65.3.0)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from ccxt) (38.0.1)
# Requirement already satisfied: aiodns>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from ccxt) (3.0.0)
# Requirement already satisfied: aiohttp>=3.8 in /usr/local/lib/python3.7/dist-packages (from ccxt) (3.8.1)
# Requirement already satisfied: multidict>=4.0 in /usr/local/lib/python3.7/dist-packages (from yarl==1.7.2->ccxt) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from yarl==1.7.2->ccxt) (4.1.1)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl==1.7.2->ccxt) (2.10)
# Requirement already satisfied: pycares>=4.0.0 in /usr/local/lib/python3.7/dist-packages (from aiodns>=1.1.1->ccxt) (4.2.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.8->ccxt) (0.13.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.8->ccxt) (1.3.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.8->ccxt) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.8->ccxt) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.8->ccxt) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp>=3.8->ccxt) (22.1.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=2.6.1->ccxt) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt) (2.21)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->ccxt) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.18.4->ccxt) (1.24.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.7/dist-packages (1.4.1)

# %%
import ccxt
import requests
import websocket
import json
from pprint import pprint
import time
from datetime import datetime

# %% [markdown]
# **Finder class**
#
# The outline of the two main class methods:
#
# **find_paths():** For finding all tradable triangular paths on Binance. This operation is executed only once before the continuous scanning. Hence, speed is not a concern.
#
# * Fetch all tickers on Binance (and filter out derivatives)
# * Fetch all traded pairs on Binance
# * Initialize order books with placeholders for bid and ask prices for all valid pairs (bid price is highest price buyers are prepared to buy; ask price is the lowest price sellers are willing to sell)
# * Brute force through all three-ticker combinations, and save those that constitute a tradeable triangular path.
# * Remove duplicate paths (t1 -> t2 -> t3 -> t1 is effectively identical as t2 -> t3 -> t1 -> t2)
# * The remaining set of paths constitutes the scanned universe.
#
# **find_arbitrage():** Process data received from websocket and scan for arbitrage opportunities. At every received payload:
#
# * Update orderbooks for each pair with the most recent bid and ask prices
# * Loop through all paths, compute the cumulative net return for trading the path, and save profitable paths
# * Print all profitable arbitrage paths with trading instructions and resulting net return
#
# See the comments and code for more details.

# %%
class TriArbFinder:

    def __init__(self):
        self.paths = list()
        self.books = dict()


    def valid_pair(self, from_tick, to_tick):
        '''
          Helper function for checking whether "from_tick" and "to_tick" constitute a valid
          trading pair, and whether the pair should be bough or sold in order to move 
          from asset "from_tick" to asset "to_tick".
        '''
        is_valid = pair = direction = None

        if from_tick + to_tick in self.books: # Check whether the pair exists in the books containing all valid pairs (= is a tradeable pair)
            pair = from_tick + to_tick        # Record the pair as level 1 trade
            direction = 'sell'                # We sell the pair @ bid to go from 'from_tick' to 'to_tick' (price is numerator)
            is_valid = True                   # Indicate that 'from_tick' and 'to_tick' constitute a valid trading pair

        if to_tick + from_tick in self.books: # Check whether the reverse pair exists in the books (only either one can be)
            pair = to_tick + from_tick
            direction = 'buy'                 # We buy the pair @ ask to go from 'from_tick' to 'to_tick' (price is denominator)
            is_valid = True

        return is_valid, pair, direction


    def find_paths(self):

        t = time.time()

        print('Identifying all triangular paths...')

        # Get all single tickers
        exchange    = ccxt.binance()
        markets     = exchange.load_markets()
        all_tickers = list(exchange.currencies)

        # Filter out derivatives
        derivatives = ('UP', 'DOWN', 'BULL', 'BEAR')  
        tickers     = [ticker for ticker in all_tickers if not (ticker.endswith(derivatives) or ticker == 'T')]

        # Get valid pairs (only a subset of all ticker combinations can be traded on Binance)
        url         = 'https://api.binance.com/api/v3/exchangeInfo'
        resp        = requests.get(url)
        einfo       = resp.json()

        valid_pairs = []
        for pair in einfo['symbols']:
            if pair['status'] == 'TRADING':
                valid_pairs.append(pair['symbol'])

        # Initialize order books for all valid pairs
        for pair in valid_pairs:
            self.books[pair] = {'bid_price': 0, 'ask_price': 0}

        # Find all possible triangular paths (from tick_1 -> tick_2 -> tick_3 -> tick_1)
        # Brute force through all three-pair combinations, and save those that construct valid, tradeable paths
        all_paths = []
        for t1 in tickers:
            for t2 in tickers:
                for t3 in tickers:
                    if not (t1 == t2 or t1 == t3 or t2 == t3): # Ensure the path goes through three distinct assets

                        # Trade 1 / t1 -> t2
                        is_valid1, pair1, direction1 = self.valid_pair(t1, t2)

                        # Trade 2 / t2 -> t3
                        is_valid2, pair2, direction2 = self.valid_pair(t2, t3)

                        # Trade 3 / t3 -> t1
                        is_valid3, pair3, direction3 = self.valid_pair(t3, t1)

                        # Chekc if valid path identified
                        if is_valid1 and is_valid2 and is_valid3:
                            p = {
                                't1': t1,
                                't2': t2,
                                't3': t3,
                                'pair1': pair1,
                                'pair2': pair2,
                                'pair3': pair3,
                                'direction1': direction1,
                                'direction2': direction2,
                                'direction3': direction3,
                                'cum_ret': -100,
                                'path': ''
                                }
                            all_paths.append(p)

        print('All possible triangular paths identified. Proceeding to remove duplicates...')

        # Remove redundant paths
        # E.g., (tick_1 -> tick_2 -> tick_3 -> tick_1) is effectively same as (tick_2 -> tick_3 -> tick_1 -> tick_2)
        # Both loops are identical, with identical return and trades, thus we'll keep only one of these to reduce computational expense
        seen_paths = []
        for p in all_paths:
            
            pot_path = p['t1'] + p['t2'] + p['t3']
            
            if not any(pot_path in s for s in seen_paths):
                
                # Append a new path to the list containing seen paths.
                # t1t2t3 becomes t1t2t3t1t2t3 when we use *2 operator on it.
                # This way the string includes the path's all starting configurations,
                # (t1->t2->t3, t2->t3->t1, and t3->t1->t2), 
                # which makes checking seen paths easy with the single line if statement above
                seen_paths.append(pot_path*2)

                # Append a new path to list containin the final set of paths that will be used by the main algorithm
                self.paths.append(p)

        t = time.time() - t
        print(f'Finished (elapsed {t:.1f} seconds).')
        print(f'Total {len(self.paths)} unique paths identified from {len(tickers)} tickers.')


    def find_arbitrage(self, data, fee=0, net_return_threshold=0):

        # Container for profitable arbitrage opportunities
        arb_paths = []
        
        # Update class orderbooks with the latest snapshot of the market data orderbooks
        for d in data:
            pair = d['s']
            self.books[pair]['bid_price'] = float(d['b'])
            self.books[pair]['ask_price'] = float(d['a'])

        # Loop through all valid triangular trading paths
        for p in self.paths:
            
            if self.books[p['pair1']]['bid_price'] != 0 and \
                self.books[p['pair2']]['bid_price'] !=0 and \
                self.books[p['pair3']]['bid_price'] != 0:
                
                cum_ret = float()
                path_str = str()

                # Trade 1
                if p['direction1']  == 'sell':
                    # SELL the pair @ BID
                    cum_ret  = self.books[p['pair1']]['bid_price']
                    path_str = f"{p['t1']} -> [{p['pair1']}][sell @ bid][{ self.books[p['pair1']]['bid_price'] }] -> {p['t2']}\n"
                else: 
                    # BUY the pair @ ASK
                    cum_ret  = 1 / self.books[p['pair1']]['ask_price']
                    path_str = f"{p['t1']} -> [{p['pair1']}][buy @ ask][{ self.books[p['pair1']]['ask_price'] }] -> {p['t2']}\n"
                
                # Trade 2
                if p['direction2']  == 'sell':
                    cum_ret  *= self.books[p['pair2']]['bid_price']
                    path_str += f"{p['t2']} -> [{p['pair2']}][sell @ bid][{ self.books[p['pair2']]['bid_price'] }] -> {p['t3']}\n"
                else:
                    cum_ret  *= 1 / self.books[p['pair2']]['ask_price']
                    path_str += f"{p['t2']} -> [{p['pair2']}][buy @ ask][{ self.books[p['pair2']]['ask_price'] }] -> {p['t3']}\n"

                # Trade 3
                if p['direction3']  == 'sell':
                    cum_ret  *= self.books[p['pair3']]['bid_price']
                    path_str += f"{p['t3']} -> [{p['pair3']}][sell @ bid][{ self.books[p['pair3']]['bid_price'] }] -> {p['t1']}\n"
                else:
                    cum_ret  *= 1 / self.books[p['pair3']]['ask_price']
                    path_str += f"{p['t3']} -> [{p['pair3']}][buy @ ask][{ self.books[p['pair3']]['ask_price'] }] -> {p['t1']}\n"

                # Append to the path element (i) the path in text format, and (ii) the cumulative roundtrip return for trading the path
                p['path'] = path_str
                p['cum_ret'] = (cum_ret - 3*fee -1)*100

                # Append to profitable arbitrage paths
                if p['cum_ret'] > net_return_threshold*100:
                    arb_paths.append(p)

        # Print profitable paths
        for ap in arb_paths:
            msg = f'''
[{datetime.now()}]
{ap['path']}
Net roundtrip return: {ap['cum_ret']:.3f} %

'''
            print(msg)

# %% [markdown]
# **Instantiate TriArbFinder**

# %%
finder = TriArbFinder()

# %% [markdown]
# **Find all triagular paths**

# %%
finder.find_paths()
# Out:
# Identifying all triangular paths...
# All possible triangular paths identified. Proceeding to remove duplicates...
# Finished (elapsed 180.0 seconds).
# Total 5314 unique paths identified from 464 tickers.

# %% [markdown]
# **Open socket and run algorithm**

# %%
# Define search parameters (specify in decimal format: 0.1% = 0.001)
fee = 0 # Fee per single trade (standard fee on Binance: 0.00075)
net_return_threshold = 0

# %%
# Define web socket functions
def on_open(ws):
    print('\nConnection opened...\n')

def on_close(ws):
    print('\nConnection closed.\n')

def on_message(ws, message):
    json_message = json.loads(message)
    finder.find_arbitrage(json_message, fee, net_return_threshold)

# %%
# Open socket connection and run algorithm
SOCKET = 'wss://stream.binance.com:9443/ws/!ticker@arr'
ws = websocket.WebSocketApp(SOCKET, 
                            on_open=on_open, 
                            on_close=on_close,
                            on_message=on_message)

ws.run_forever()
# Out:
# WARNING:websocket:websocket connected
# Connection opened...
#
#
# [2022-09-17 14:24:00.665215]
# AERGO -> [AERGOBTC][sell @ bid][7.15e-06] -> BTC
# BTC -> [BTCBUSD][sell @ bid][19916.66] -> BUSD
# BUSD -> [AERGOBUSD][buy @ ask][0.1424] -> AERGO
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:00.665380]
# ALICE -> [ALICETRY][sell @ bid][37.37] -> TRY
# TRY -> [BTCTRY][buy @ ask][368816.0] -> BTC
# BTC -> [ALICEBTC][buy @ ask][0.0001013] -> ALICE
#
# Net roundtrip return: 0.024 %
#
#
#
# [2022-09-17 14:24:00.665425]
# ALICE -> [ALICETRY][sell @ bid][37.37] -> TRY
# TRY -> [BUSDTRY][buy @ ask][18.514] -> BUSD
# BUSD -> [ALICEBUSD][buy @ ask][2.018] -> ALICE
#
# Net roundtrip return: 0.023 %
#
#
#
# [2022-09-17 14:24:00.665461]
# BNB -> [BNBBTC][sell @ bid][0.01391] -> BTC
# BTC -> [WAVESBTC][buy @ ask][0.0002167] -> WAVES
# WAVES -> [WAVESBNB][sell @ bid][0.01558] -> BNB
#
# Net roundtrip return: 0.008 %
#
#
#
# [2022-09-17 14:24:00.665511]
# BNB -> [BNBUSDC][sell @ bid][277.1] -> USDC
# USDC -> [BTCUSDC][buy @ ask][19918.28] -> BTC
# BTC -> [BNBBTC][buy @ ask][0.013911] -> BNB
#
# Net roundtrip return: 0.006 %
#
#
#
# [2022-09-17 14:24:00.665546]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19917.1] -> BTC
# BTC -> [BNBBTC][buy @ ask][0.013911] -> BNB
#
# Net roundtrip return: 0.012 %
#
#
#
# [2022-09-17 14:24:00.666469]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [SANDUSDT][buy @ ask][0.8947] -> SAND
# SAND -> [SANDBNB][sell @ bid][0.003229] -> BNB
#
# Net roundtrip return: 0.006 %
#
#
#
# [2022-09-17 14:24:00.666544]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [SXPUSDT][buy @ ask][0.3543] -> SXP
# SXP -> [SXPBNB][sell @ bid][0.001279] -> BNB
#
# Net roundtrip return: 0.031 %
#
#
#
# [2022-09-17 14:24:00.666582]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [XMRUSDT][buy @ ask][150.7] -> XMR
# XMR -> [XMRBNB][sell @ bid][0.544] -> BNB
#
# Net roundtrip return: 0.028 %
#
#
#
# [2022-09-17 14:24:00.666618]
# BTC -> [DOGEBTC][buy @ ask][3.1e-06] -> DOGE
# DOGE -> [DOGEBUSD][sell @ bid][0.06175] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19917.34] -> BTC
#
# Net roundtrip return: 0.010 %
#
#
#
# [2022-09-17 14:24:00.666651]
# BTC -> [ETHBTC][buy @ ask][0.071794] -> ETH
# ETH -> [ETHUSDC][sell @ bid][1430.09] -> USDC
# USDC -> [BTCUSDC][buy @ ask][19918.28] -> BTC
#
# Net roundtrip return: 0.005 %
#
#
#
# [2022-09-17 14:24:00.667372]
# BTC -> [ETHBTC][buy @ ask][0.071794] -> ETH
# ETH -> [ETHUSDT][sell @ bid][1429.98] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19917.1] -> BTC
#
# Net roundtrip return: 0.004 %
#
#
#
# [2022-09-17 14:24:00.667441]
# BTC -> [MATICBTC][buy @ ask][4.106e-05] -> MATIC
# MATIC -> [MATICBUSD][sell @ bid][0.8179] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19917.34] -> BTC
#
# Net roundtrip return: 0.011 %
#
#
#
# [2022-09-17 14:24:00.667479]
# BTC -> [SOLBTC][buy @ ask][0.0016577] -> SOL
# SOL -> [SOLBUSD][sell @ bid][33.02] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19917.34] -> BTC
#
# Net roundtrip return: 0.009 %
#
#
#
# [2022-09-17 14:24:00.667514]
# BUSD -> [LUNCBUSD][buy @ ask][0.0003078] -> LUNC
# LUNC -> [LUNCUSDT][sell @ bid][0.00030783] -> USDT
# USDT -> [BUSDUSDT][buy @ ask][1.0] -> BUSD
#
# Net roundtrip return: 0.010 %
#
#
#
# [2022-09-17 14:24:00.667548]
# BUSD -> [BUSDTRY][sell @ bid][18.513] -> TRY
# TRY -> [LRCTRY][buy @ ask][6.08] -> LRC
# LRC -> [LRCBUSD][sell @ bid][0.3285] -> BUSD
#
# Net roundtrip return: 0.025 %
#
#
#
# [2022-09-17 14:24:00.667582]
# BUSD -> [BUSDUSDT][sell @ bid][0.9999] -> USDT
# USDT -> [LUNAUSDT][buy @ ask][3.0493] -> LUNA
# LUNA -> [LUNABUSD][sell @ bid][3.0498] -> BUSD
#
# Net roundtrip return: 0.006 %
#
#
#
# [2022-09-17 14:24:00.667615]
# BUSD -> [BUSDUSDT][sell @ bid][0.9999] -> USDT
# USDT -> [MATICUSDT][buy @ ask][0.8178] -> MATIC
# MATIC -> [MATICBUSD][sell @ bid][0.8179] -> BUSD
#
# Net roundtrip return: 0.002 %
#
#
#
# [2022-09-17 14:24:00.667648]
# ETH -> [ETHTRY][sell @ bid][26476.0] -> TRY
# TRY -> [TRXTRY][buy @ ask][1.1442] -> TRX
# TRX -> [TRXETH][sell @ bid][4.322e-05] -> ETH
#
# Net roundtrip return: 0.008 %
#
#
#
# [2022-09-17 14:24:00.667682]
# ETH -> [ETHTRY][sell @ bid][26476.0] -> TRY
# TRY -> [XRPTRY][buy @ ask][6.952] -> XRP
# XRP -> [XRPETH][sell @ bid][0.0002626] -> ETH
#
# Net roundtrip return: 0.009 %
#
#
#
# [2022-09-17 14:24:00.667716]
# EUR -> [EURUSDT][sell @ bid][1.0004] -> USDT
# USDT -> [MATICUSDT][buy @ ask][0.8178] -> MATIC
# MATIC -> [MATICEUR][sell @ bid][0.8175] -> EUR
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:01.317654]
# ALICE -> [ALICETRY][sell @ bid][37.37] -> TRY
# TRY -> [BTCTRY][buy @ ask][368785.0] -> BTC
# BTC -> [ALICEBTC][buy @ ask][0.0001013] -> ALICE
#
# Net roundtrip return: 0.032 %
#
#
#
# [2022-09-17 14:24:01.318366]
# ALICE -> [ALICETRY][sell @ bid][37.37] -> TRY
# TRY -> [BUSDTRY][buy @ ask][18.514] -> BUSD
# BUSD -> [ALICEBUSD][buy @ ask][2.018] -> ALICE
#
# Net roundtrip return: 0.023 %
#
#
#
# [2022-09-17 14:24:01.318430]
# ALICE -> [ALICETRY][sell @ bid][37.37] -> TRY
# TRY -> [USDTTRY][buy @ ask][18.514] -> USDT
# USDT -> [ALICEUSDT][buy @ ask][2.018] -> ALICE
#
# Net roundtrip return: 0.023 %
#
#
#
# [2022-09-17 14:24:01.318469]
# ATOM -> [ATOMBUSD][sell @ bid][16.27] -> BUSD
# BUSD -> [BUSDTRY][sell @ bid][18.513] -> TRY
# TRY -> [ATOMTRY][buy @ ask][301.2] -> ATOM
#
# Net roundtrip return: 0.002 %
#
#
#
# [2022-09-17 14:24:01.318502]
# BNB -> [BNBUSDC][sell @ bid][277.1] -> USDC
# USDC -> [BTCUSDC][buy @ ask][19917.57] -> BTC
# BTC -> [BNBBTC][buy @ ask][0.013911] -> BNB
#
# Net roundtrip return: 0.010 %
#
#
#
# [2022-09-17 14:24:01.318534]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19916.52] -> BTC
# BTC -> [BNBBTC][buy @ ask][0.013911] -> BNB
#
# Net roundtrip return: 0.015 %
#
#
#
# [2022-09-17 14:24:01.318569]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [ENJUSDT][buy @ ask][0.5057] -> ENJ
# ENJ -> [ENJBNB][sell @ bid][0.001825] -> BNB
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:01.318794]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [SXPUSDT][buy @ ask][0.3543] -> SXP
# SXP -> [SXPBNB][sell @ bid][0.001279] -> BNB
#
# Net roundtrip return: 0.031 %
#
#
#
# [2022-09-17 14:24:01.318863]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [XMRUSDT][buy @ ask][150.7] -> XMR
# XMR -> [XMRBNB][sell @ bid][0.544] -> BNB
#
# Net roundtrip return: 0.028 %
#
#
#
# [2022-09-17 14:24:01.319955]
# BRL -> [SANDBRL][buy @ ask][4.7] -> SAND
# SAND -> [SANDBTC][sell @ bid][4.493e-05] -> BTC
# BTC -> [BTCBRL][sell @ bid][104977.0] -> BRL
#
# Net roundtrip return: 0.354 %
#
#
#
# [2022-09-17 14:24:01.320058]
# BRL -> [SANDBRL][buy @ ask][4.7] -> SAND
# SAND -> [SANDBUSD][sell @ bid][0.8947] -> BUSD
# BUSD -> [BUSDBRL][sell @ bid][5.27] -> BRL
#
# Net roundtrip return: 0.321 %
#
#
#
# [2022-09-17 14:24:01.320100]
# BRL -> [SANDBRL][buy @ ask][4.7] -> SAND
# SAND -> [SANDUSDT][sell @ bid][0.8947] -> USDT
# USDT -> [USDTBRL][sell @ bid][5.27] -> BRL
#
# Net roundtrip return: 0.321 %
#
#
#
# [2022-09-17 14:24:01.320143]
# BTC -> [BTCBUSD][sell @ bid][19916.08] -> BUSD
# BUSD -> [SANDBUSD][buy @ ask][0.8948] -> SAND
# SAND -> [SANDBTC][sell @ bid][4.493e-05] -> BTC
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:01.320178]
# BTC -> [ETHBTC][buy @ ask][0.071798] -> ETH
# ETH -> [ETHBUSD][sell @ bid][1430.0] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.66] -> BTC
#
# Net roundtrip return: 0.002 %
#
#
#
# [2022-09-17 14:24:01.320212]
# BTC -> [ETHBTC][buy @ ask][0.071798] -> ETH
# ETH -> [ETHUSDT][sell @ bid][1429.98] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19916.52] -> BTC
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:01.320246]
# BTC -> [BTCEUR][sell @ bid][19907.24] -> EUR
# EUR -> [EURBUSD][sell @ bid][1.0005] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.66] -> BTC
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:01.320280]
# BTC -> [LINKBTC][buy @ ask][0.000397] -> LINK
# LINK -> [LINKBUSD][sell @ bid][7.907] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.66] -> BTC
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:01.320313]
# BTC -> [MATICBTC][buy @ ask][4.106e-05] -> MATIC
# MATIC -> [MATICBUSD][sell @ bid][0.8178] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.66] -> BTC
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:01.320346]
# BTC -> [SOLBTC][buy @ ask][0.0016578] -> SOL
# SOL -> [SOLBUSD][sell @ bid][33.02] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.66] -> BTC
#
# Net roundtrip return: 0.007 %
#
#
#
# [2022-09-17 14:24:01.320381]
# BTC -> [BTCUSDT][sell @ bid][19916.25] -> USDT
# USDT -> [SANDUSDT][buy @ ask][0.8948] -> SAND
# SAND -> [SANDBTC][sell @ bid][4.493e-05] -> BTC
#
# Net roundtrip return: 0.004 %
#
#
#
# [2022-09-17 14:24:01.320415]
# BTC -> [WAVESBTC][buy @ ask][0.0002167] -> WAVES
# WAVES -> [WAVESBUSD][sell @ bid][4.316] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.66] -> BTC
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:01.320448]
# BTC -> [WAVESBTC][buy @ ask][0.0002167] -> WAVES
# WAVES -> [WAVESUSDT][sell @ bid][4.316] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19916.52] -> BTC
#
# Net roundtrip return: 0.002 %
#
#
#
# [2022-09-17 14:24:01.320482]
# BTC -> [XTZBTC][buy @ ask][7.722e-05] -> XTZ
# XTZ -> [XTZBUSD][sell @ bid][1.538] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.66] -> BTC
#
# Net roundtrip return: 0.002 %
#
#
#
# [2022-09-17 14:24:01.320534]
# BTC -> [XTZBTC][buy @ ask][7.722e-05] -> XTZ
# XTZ -> [XTZUSDT][sell @ bid][1.538] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19916.52] -> BTC
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:01.320569]
# BTC -> [ZENBTC][buy @ ask][0.000734] -> ZEN
# ZEN -> [ZENUSDT][sell @ bid][14.63] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19916.52] -> BTC
#
# Net roundtrip return: 0.077 %
#
#
#
# [2022-09-17 14:24:01.320611]
# BUSD -> [ETHBUSD][buy @ ask][1430.05] -> ETH
# ETH -> [ETHEUR][sell @ bid][1429.36] -> EUR
# EUR -> [EURBUSD][sell @ bid][1.0005] -> BUSD
#
# Net roundtrip return: 0.002 %
#
#
#
# [2022-09-17 14:24:01.320646]
# BUSD -> [ETHBUSD][buy @ ask][1430.05] -> ETH
# ETH -> [ETHTRY][sell @ bid][26476.0] -> TRY
# TRY -> [BUSDTRY][buy @ ask][18.514] -> BUSD
#
# Net roundtrip return: 0.000 %
#
#
#
# [2022-09-17 14:24:01.320679]
# BUSD -> [LUNCBUSD][buy @ ask][0.00030773] -> LUNC
# LUNC -> [LUNCUSDT][sell @ bid][0.00030784] -> USDT
# USDT -> [BUSDUSDT][buy @ ask][1.0] -> BUSD
#
# Net roundtrip return: 0.036 %
#
#
#
# [2022-09-17 14:24:01.320713]
# BUSD -> [MATICBUSD][buy @ ask][0.8179] -> MATIC
# MATIC -> [MATICEUR][sell @ bid][0.8175] -> EUR
# EUR -> [EURBUSD][sell @ bid][1.0005] -> BUSD
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:01.320748]
# BUSD -> [BUSDTRY][sell @ bid][18.513] -> TRY
# TRY -> [LRCTRY][buy @ ask][6.08] -> LRC
# LRC -> [LRCBUSD][sell @ bid][0.3285] -> BUSD
#
# Net roundtrip return: 0.025 %
#
#
#
# [2022-09-17 14:24:01.320782]
# BUSD -> [BUSDUSDT][sell @ bid][0.9999] -> USDT
# USDT -> [LUNAUSDT][buy @ ask][3.0493] -> LUNA
# LUNA -> [LUNABUSD][sell @ bid][3.0498] -> BUSD
#
# Net roundtrip return: 0.006 %
#
#
#
# [2022-09-17 14:24:01.320816]
# EGLD -> [EGLDEUR][sell @ bid][50.89] -> EUR
# EUR -> [EURUSDT][sell @ bid][1.0004] -> USDT
# USDT -> [EGLDUSDT][buy @ ask][50.91] -> EGLD
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:01.320850]
# ETH -> [ETHEUR][sell @ bid][1429.36] -> EUR
# EUR -> [XLMEUR][buy @ ask][0.1109] -> XLM
# XLM -> [XLMETH][sell @ bid][7.76e-05] -> ETH
#
# Net roundtrip return: 0.017 %
#
#
#
# [2022-09-17 14:24:01.320884]
# ETH -> [ETHTRY][sell @ bid][26476.0] -> TRY
# TRY -> [TRXTRY][buy @ ask][1.1442] -> TRX
# TRX -> [TRXETH][sell @ bid][4.322e-05] -> ETH
#
# Net roundtrip return: 0.008 %
#
#
#
# [2022-09-17 14:24:01.320918]
# ETH -> [ETHTRY][sell @ bid][26476.0] -> TRY
# TRY -> [USDTTRY][buy @ ask][18.514] -> USDT
# USDT -> [ETHUSDT][buy @ ask][1429.99] -> ETH
#
# Net roundtrip return: 0.004 %
#
#
#
# [2022-09-17 14:24:01.320953]
# EUR -> [EURUSDT][sell @ bid][1.0004] -> USDT
# USDT -> [MATICUSDT][buy @ ask][0.8178] -> MATIC
# MATIC -> [MATICEUR][sell @ bid][0.8175] -> EUR
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:01.320986]
# LRC -> [LRCUSDT][sell @ bid][0.3285] -> USDT
# USDT -> [USDTTRY][sell @ bid][18.513] -> TRY
# TRY -> [LRCTRY][buy @ ask][6.08] -> LRC
#
# Net roundtrip return: 0.025 %
#
#
#
# [2022-09-17 14:24:01.321016]
# ROSE -> [ROSETRY][sell @ bid][1.145] -> TRY
# TRY -> [USDTTRY][buy @ ask][18.514] -> USDT
# USDT -> [ROSEUSDT][buy @ ask][0.06184] -> ROSE
#
# Net roundtrip return: 0.008 %
#
#
#
# [2022-09-17 14:24:02.138525]
# AERGO -> [AERGOBTC][sell @ bid][7.15e-06] -> BTC
# BTC -> [BTCBUSD][sell @ bid][19916.33] -> BUSD
# BUSD -> [AERGOBUSD][buy @ ask][0.1424] -> AERGO
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:02.139581]
# AGLD -> [AGLDBUSD][sell @ bid][0.354] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.34] -> BTC
# BTC -> [AGLDBTC][buy @ ask][1.777e-05] -> AGLD
#
# Net roundtrip return: 0.024 %
#
#
#
# [2022-09-17 14:24:02.139937]
# ALICE -> [ALICETRY][sell @ bid][37.37] -> TRY
# TRY -> [BTCTRY][buy @ ask][368783.0] -> BTC
# BTC -> [ALICEBTC][buy @ ask][0.0001013] -> ALICE
#
# Net roundtrip return: 0.033 %
#
#
#
# [2022-09-17 14:24:02.140350]
# ALICE -> [ALICETRY][sell @ bid][37.37] -> TRY
# TRY -> [BUSDTRY][buy @ ask][18.514] -> BUSD
# BUSD -> [ALICEBUSD][buy @ ask][2.018] -> ALICE
#
# Net roundtrip return: 0.023 %
#
#
#
# [2022-09-17 14:24:02.140717]
# ALICE -> [ALICETRY][sell @ bid][37.37] -> TRY
# TRY -> [USDTTRY][buy @ ask][18.514] -> USDT
# USDT -> [ALICEUSDT][buy @ ask][2.018] -> ALICE
#
# Net roundtrip return: 0.023 %
#
#
#
# [2022-09-17 14:24:02.141081]
# APE -> [APEBUSD][sell @ bid][4.815] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.34] -> BTC
# BTC -> [APEBTC][buy @ ask][0.00024176] -> APE
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:02.141451]
# ATOM -> [ATOMBUSD][sell @ bid][16.27] -> BUSD
# BUSD -> [BUSDTRY][sell @ bid][18.513] -> TRY
# TRY -> [ATOMTRY][buy @ ask][301.2] -> ATOM
#
# Net roundtrip return: 0.002 %
#
#
#
# [2022-09-17 14:24:02.141776]
# BETA -> [BETABUSD][sell @ bid][0.10167] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.34] -> BTC
# BTC -> [BETABTC][buy @ ask][5.1e-06] -> BETA
#
# Net roundtrip return: 0.095 %
#
#
#
# [2022-09-17 14:24:02.142153]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19916.5] -> BTC
# BTC -> [BNBBTC][buy @ ask][0.013911] -> BNB
#
# Net roundtrip return: 0.015 %
#
#
#
# [2022-09-17 14:24:02.142515]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [ENJUSDT][buy @ ask][0.5057] -> ENJ
# ENJ -> [ENJBNB][sell @ bid][0.001825] -> BNB
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:02.142846]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [SXPUSDT][buy @ ask][0.3543] -> SXP
# SXP -> [SXPBNB][sell @ bid][0.001279] -> BNB
#
# Net roundtrip return: 0.031 %
#
#
#
# [2022-09-17 14:24:02.143195]
# BRL -> [SANDBRL][buy @ ask][4.7] -> SAND
# SAND -> [SANDBTC][sell @ bid][4.493e-05] -> BTC
# BTC -> [BTCBRL][sell @ bid][104973.0] -> BRL
#
# Net roundtrip return: 0.350 %
#
#
#
# [2022-09-17 14:24:02.143541]
# BRL -> [SANDBRL][buy @ ask][4.7] -> SAND
# SAND -> [SANDBUSD][sell @ bid][0.8947] -> BUSD
# BUSD -> [BUSDBRL][sell @ bid][5.27] -> BRL
#
# Net roundtrip return: 0.321 %
#
#
#
# [2022-09-17 14:24:02.143868]
# BRL -> [SANDBRL][buy @ ask][4.7] -> SAND
# SAND -> [SANDETH][sell @ bid][0.0006256] -> ETH
# ETH -> [ETHBRL][sell @ bid][7536.59] -> BRL
#
# Net roundtrip return: 0.317 %
#
#
#
# [2022-09-17 14:24:02.144250]
# BRL -> [SANDBRL][buy @ ask][4.7] -> SAND
# SAND -> [SANDUSDT][sell @ bid][0.8948] -> USDT
# USDT -> [USDTBRL][sell @ bid][5.27] -> BRL
#
# Net roundtrip return: 0.332 %
#
#
#
# [2022-09-17 14:24:02.144285]
# BTC -> [BTCBUSD][sell @ bid][19916.33] -> BUSD
# BUSD -> [SANDBUSD][buy @ ask][0.8948] -> SAND
# SAND -> [SANDBTC][sell @ bid][4.493e-05] -> BTC
#
# Net roundtrip return: 0.005 %
#
#
#
# [2022-09-17 14:24:02.144303]
# BTC -> [CHZBTC][buy @ ask][1.076e-05] -> CHZ
# CHZ -> [CHZBUSD][sell @ bid][0.2143] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.34] -> BTC
#
# Net roundtrip return: 0.000 %
#
#
#
# [2022-09-17 14:24:02.144320]
# BTC -> [ETHBTC][buy @ ask][0.071798] -> ETH
# ETH -> [ETHBUSD][sell @ bid][1430.0] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.34] -> BTC
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:02.144337]
# BTC -> [ETHBTC][buy @ ask][0.071798] -> ETH
# ETH -> [ETHUSDC][sell @ bid][1430.06] -> USDC
# USDC -> [BTCUSDC][buy @ ask][19917.08] -> BTC
#
# Net roundtrip return: 0.004 %
#
#
#
# [2022-09-17 14:24:02.144353]
# BTC -> [ETHBTC][buy @ ask][0.071798] -> ETH
# ETH -> [ETHUSDT][sell @ bid][1429.98] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19916.5] -> BTC
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:02.144416]
# BTC -> [BTCEUR][sell @ bid][19906.59] -> EUR
# EUR -> [EURBUSD][sell @ bid][1.0005] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.34] -> BTC
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:02.144433]
# BTC -> [LINKBTC][buy @ ask][0.000397] -> LINK
# LINK -> [LINKBUSD][sell @ bid][7.907] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.34] -> BTC
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:02.144450]
# BTC -> [LTCBTC][buy @ ask][0.002895] -> LTC
# LTC -> [LTCBUSD][sell @ bid][57.66] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.34] -> BTC
#
# Net roundtrip return: 0.004 %
#
#
#
# [2022-09-17 14:24:02.144466]
# BTC -> [SOLBTC][buy @ ask][0.0016578] -> SOL
# SOL -> [SOLBUSD][sell @ bid][33.02] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.34] -> BTC
#
# Net roundtrip return: 0.008 %
#
#
#
# [2022-09-17 14:24:02.144482]
# BTC -> [STRAXBTC][buy @ ask][2.825e-05] -> STRAX
# STRAX -> [STRAXUSDT][sell @ bid][0.563] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19916.5] -> BTC
#
# Net roundtrip return: 0.064 %
#
#
#
# [2022-09-17 14:24:02.144498]
# BTC -> [BTCTRY][sell @ bid][368734.0] -> TRY
# TRY -> [BUSDTRY][buy @ ask][18.514] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.34] -> BTC
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:02.144514]
# BTC -> [WAVESBTC][buy @ ask][0.0002167] -> WAVES
# WAVES -> [WAVESBUSD][sell @ bid][4.316] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.34] -> BTC
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:02.144530]
# BTC -> [WAVESBTC][buy @ ask][0.0002167] -> WAVES
# WAVES -> [WAVESUSDT][sell @ bid][4.316] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19916.5] -> BTC
#
# Net roundtrip return: 0.002 %
#
#
#
# [2022-09-17 14:24:02.144546]
# BTC -> [XTZBTC][buy @ ask][7.722e-05] -> XTZ
# XTZ -> [XTZBUSD][sell @ bid][1.538] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19916.34] -> BTC
#
# Net roundtrip return: 0.004 %
#
#
#
# [2022-09-17 14:24:02.144564]
# BTC -> [XTZBTC][buy @ ask][7.722e-05] -> XTZ
# XTZ -> [XTZUSDT][sell @ bid][1.538] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19916.5] -> BTC
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:02.144580]
# BTC -> [ZENBTC][buy @ ask][0.000734] -> ZEN
# ZEN -> [ZENUSDT][sell @ bid][14.63] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19916.5] -> BTC
#
# Net roundtrip return: 0.077 %
#
#
#
# [2022-09-17 14:24:02.144595]
# BUSD -> [LUNCBUSD][buy @ ask][0.00030777] -> LUNC
# LUNC -> [LUNCUSDT][sell @ bid][0.00030783] -> USDT
# USDT -> [BUSDUSDT][buy @ ask][1.0] -> BUSD
#
# Net roundtrip return: 0.019 %
#
#
#
# [2022-09-17 14:24:02.144610]
# BUSD -> [BUSDTRY][sell @ bid][18.513] -> TRY
# TRY -> [LRCTRY][buy @ ask][6.08] -> LRC
# LRC -> [LRCBUSD][sell @ bid][0.3285] -> BUSD
#
# Net roundtrip return: 0.025 %
#
#
#
# [2022-09-17 14:24:02.144625]
# BUSD -> [BUSDTRY][sell @ bid][18.513] -> TRY
# TRY -> [TRXTRY][buy @ ask][1.1442] -> TRX
# TRX -> [TRXBUSD][sell @ bid][0.06181] -> BUSD
#
# Net roundtrip return: 0.008 %
#
#
#
# [2022-09-17 14:24:02.144640]
# BUSD -> [BUSDUSDT][sell @ bid][0.9999] -> USDT
# USDT -> [LUNAUSDT][buy @ ask][3.0494] -> LUNA
# LUNA -> [LUNABUSD][sell @ bid][3.05] -> BUSD
#
# Net roundtrip return: 0.010 %
#
#
#
# [2022-09-17 14:24:02.144654]
# BUSD -> [BUSDUSDT][sell @ bid][0.9999] -> USDT
# USDT -> [MATICUSDT][buy @ ask][0.8178] -> MATIC
# MATIC -> [MATICBUSD][sell @ bid][0.8179] -> BUSD
#
# Net roundtrip return: 0.002 %
#
#
#
# [2022-09-17 14:24:02.144669]
# EGLD -> [EGLDEUR][sell @ bid][50.89] -> EUR
# EUR -> [EURUSDT][sell @ bid][1.0004] -> USDT
# USDT -> [EGLDUSDT][buy @ ask][50.91] -> EGLD
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:02.144729]
# ETH -> [ETHEUR][sell @ bid][1429.36] -> EUR
# EUR -> [XLMEUR][buy @ ask][0.1109] -> XLM
# XLM -> [XLMETH][sell @ bid][7.76e-05] -> ETH
#
# Net roundtrip return: 0.017 %
#
#
#
# [2022-09-17 14:24:02.144745]
# ETH -> [ETHTRY][sell @ bid][26476.0] -> TRY
# TRY -> [TRXTRY][buy @ ask][1.1442] -> TRX
# TRX -> [TRXETH][sell @ bid][4.322e-05] -> ETH
#
# Net roundtrip return: 0.008 %
#
#
#
# [2022-09-17 14:24:02.144760]
# ETH -> [ETHTRY][sell @ bid][26476.0] -> TRY
# TRY -> [USDTTRY][buy @ ask][18.514] -> USDT
# USDT -> [ETHUSDT][buy @ ask][1429.99] -> ETH
#
# Net roundtrip return: 0.004 %
#
#
#
# [2022-09-17 14:24:02.144780]
# ETH -> [ETHUSDC][sell @ bid][1430.06] -> USDC
# USDC -> [SOLUSDC][buy @ ask][33.02] -> SOL
# SOL -> [SOLETH][sell @ bid][0.02309] -> ETH
#
# Net roundtrip return: 0.000 %
#
#
#
# [2022-09-17 14:24:02.144795]
# EUR -> [EURUSDT][sell @ bid][1.0004] -> USDT
# USDT -> [MATICUSDT][buy @ ask][0.8178] -> MATIC
# MATIC -> [MATICEUR][sell @ bid][0.8175] -> EUR
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:02.144810]
# ROSE -> [ROSETRY][sell @ bid][1.145] -> TRY
# TRY -> [USDTTRY][buy @ ask][18.514] -> USDT
# USDT -> [ROSEUSDT][buy @ ask][0.06184] -> ROSE
#
# Net roundtrip return: 0.008 %
#
#
#
# [2022-09-17 14:24:03.141834]
# AERGO -> [AERGOBTC][sell @ bid][7.15e-06] -> BTC
# BTC -> [BTCBUSD][sell @ bid][19916.4] -> BUSD
# BUSD -> [AERGOBUSD][buy @ ask][0.1424] -> AERGO
#
# Net roundtrip return: 0.002 %
#
#
#
# [2022-09-17 14:24:03.142531]
# AGLD -> [AGLDBUSD][sell @ bid][0.354] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19917.4] -> BTC
# BTC -> [AGLDBTC][buy @ ask][1.777e-05] -> AGLD
#
# Net roundtrip return: 0.019 %
#
#
#
# [2022-09-17 14:24:03.142589]
# ALICE -> [ALICETRY][sell @ bid][37.37] -> TRY
# TRY -> [BTCTRY][buy @ ask][368795.0] -> BTC
# BTC -> [ALICEBTC][buy @ ask][0.0001013] -> ALICE
#
# Net roundtrip return: 0.030 %
#
#
#
# [2022-09-17 14:24:03.142627]
# ALICE -> [ALICETRY][sell @ bid][37.37] -> TRY
# TRY -> [BUSDTRY][buy @ ask][18.514] -> BUSD
# BUSD -> [ALICEBUSD][buy @ ask][2.018] -> ALICE
#
# Net roundtrip return: 0.023 %
#
#
#
# [2022-09-17 14:24:03.142662]
# ALICE -> [ALICETRY][sell @ bid][37.37] -> TRY
# TRY -> [USDTTRY][buy @ ask][18.514] -> USDT
# USDT -> [ALICEUSDT][buy @ ask][2.018] -> ALICE
#
# Net roundtrip return: 0.023 %
#
#
#
# [2022-09-17 14:24:03.142695]
# BETA -> [BETABUSD][sell @ bid][0.10167] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19917.4] -> BTC
# BTC -> [BETABTC][buy @ ask][5.1e-06] -> BETA
#
# Net roundtrip return: 0.090 %
#
#
#
# [2022-09-17 14:24:03.142730]
# BNB -> [MANABNB][buy @ ask][0.002691] -> MANA
# MANA -> [MANABUSD][sell @ bid][0.7457] -> BUSD
# BUSD -> [BNBBUSD][buy @ ask][277.1] -> BNB
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:03.142764]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19917.44] -> BTC
# BTC -> [BNBBTC][buy @ ask][0.013911] -> BNB
#
# Net roundtrip return: 0.010 %
#
#
#
# [2022-09-17 14:24:03.142798]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [ENJUSDT][buy @ ask][0.5057] -> ENJ
# ENJ -> [ENJBNB][sell @ bid][0.001825] -> BNB
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:03.142831]
# BNB -> [BNBUSDT][sell @ bid][277.1] -> USDT
# USDT -> [SXPUSDT][buy @ ask][0.3543] -> SXP
# SXP -> [SXPBNB][sell @ bid][0.001279] -> BNB
#
# Net roundtrip return: 0.031 %
#
#
#
# [2022-09-17 14:24:03.142864]
# BRL -> [SANDBRL][buy @ ask][4.7] -> SAND
# SAND -> [SANDBTC][sell @ bid][4.493e-05] -> BTC
# BTC -> [BTCBRL][sell @ bid][104973.0] -> BRL
#
# Net roundtrip return: 0.350 %
#
#
#
# [2022-09-17 14:24:03.143722]
# BRL -> [SANDBRL][buy @ ask][4.7] -> SAND
# SAND -> [SANDBUSD][sell @ bid][0.8947] -> BUSD
# BUSD -> [BUSDBRL][sell @ bid][5.27] -> BRL
#
# Net roundtrip return: 0.321 %
#
#
#
# [2022-09-17 14:24:03.144443]
# BRL -> [SANDBRL][buy @ ask][4.7] -> SAND
# SAND -> [SANDETH][sell @ bid][0.0006256] -> ETH
# ETH -> [ETHBRL][sell @ bid][7536.59] -> BRL
#
# Net roundtrip return: 0.317 %
#
#
#
# [2022-09-17 14:24:03.144508]
# BRL -> [SANDBRL][buy @ ask][4.7] -> SAND
# SAND -> [SANDUSDT][sell @ bid][0.8948] -> USDT
# USDT -> [USDTBRL][sell @ bid][5.27] -> BRL
#
# Net roundtrip return: 0.332 %
#
#
#
# [2022-09-17 14:24:03.144545]
# BTC -> [BTCBUSD][sell @ bid][19916.4] -> BUSD
# BUSD -> [SANDBUSD][buy @ ask][0.8948] -> SAND
# SAND -> [SANDBTC][sell @ bid][4.493e-05] -> BTC
#
# Net roundtrip return: 0.005 %
#
#
#
# [2022-09-17 14:24:03.144581]
# BTC -> [ETHBTC][buy @ ask][0.071798] -> ETH
# ETH -> [ETHUSDC][sell @ bid][1430.06] -> USDC
# USDC -> [BTCUSDC][buy @ ask][19917.08] -> BTC
#
# Net roundtrip return: 0.004 %
#
#
#
# [2022-09-17 14:24:03.144614]
# BTC -> [SOLBTC][buy @ ask][0.0016578] -> SOL
# SOL -> [SOLBUSD][sell @ bid][33.02] -> BUSD
# BUSD -> [BTCBUSD][buy @ ask][19917.4] -> BTC
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:03.144648]
# BTC -> [STRAXBTC][buy @ ask][2.825e-05] -> STRAX
# STRAX -> [STRAXUSDT][sell @ bid][0.563] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19917.44] -> BTC
#
# Net roundtrip return: 0.059 %
#
#
#
# [2022-09-17 14:24:03.144682]
# BTC -> [ZENBTC][buy @ ask][0.000734] -> ZEN
# ZEN -> [ZENUSDT][sell @ bid][14.63] -> USDT
# USDT -> [BTCUSDT][buy @ ask][19917.44] -> BTC
#
# Net roundtrip return: 0.072 %
#
#
#
# [2022-09-17 14:24:03.144715]
# BUSD -> [LUNCBUSD][buy @ ask][0.0003078] -> LUNC
# LUNC -> [LUNCUSDT][sell @ bid][0.00030781] -> USDT
# USDT -> [BUSDUSDT][buy @ ask][1.0] -> BUSD
#
# Net roundtrip return: 0.003 %
#
#
#
# [2022-09-17 14:24:03.144750]
# BUSD -> [BUSDTRY][sell @ bid][18.513] -> TRY
# TRY -> [LRCTRY][buy @ ask][6.08] -> LRC
# LRC -> [LRCBUSD][sell @ bid][0.3285] -> BUSD
#
# Net roundtrip return: 0.025 %
#
#
#
# [2022-09-17 14:24:03.144783]
# BUSD -> [BUSDUSDT][sell @ bid][0.9999] -> USDT
# USDT -> [LUNAUSDT][buy @ ask][3.0494] -> LUNA
# LUNA -> [LUNABUSD][sell @ bid][3.05] -> BUSD
#
# Net roundtrip return: 0.010 %
#
#
#
# [2022-09-17 14:24:03.144816]
# EGLD -> [EGLDEUR][sell @ bid][50.89] -> EUR
# EUR -> [EURUSDT][sell @ bid][1.0004] -> USDT
# USDT -> [EGLDUSDT][buy @ ask][50.91] -> EGLD
#
# Net roundtrip return: 0.001 %
#
#
#
# [2022-09-17 14:24:03.144925]
# ETH -> [ETHEUR][sell @ bid][1429.36] -> EUR
# EUR -> [XLMEUR][buy @ ask][0.1109] -> XLM
# XLM -> [XLMETH][sell @ bid][7.76e-05] -> ETH
#
# Net roundtrip return: 0.017 %
#
#
#
# [2022-09-17 14:24:03.144962]
# ETH -> [ETHTRY][sell @ bid][26476.0] -> TRY
# TRY -> [USDTTRY][buy @ ask][18.514] -> USDT
# USDT -> [ETHUSDT][buy @ ask][1429.99] -> ETH
#
# Net roundtrip return: 0.004 %
#
#
#
# [2022-09-17 14:24:03.144996]
# ETH -> [ETHUSDC][sell @ bid][1430.06] -> USDC
# USDC -> [SOLUSDC][buy @ ask][33.02] -> SOL
# SOL -> [SOLETH][sell @ bid][0.02309] -> ETH
#
# Net roundtrip return: 0.000 %
#
#
#
# [2022-09-17 14:24:03.145039]
# HOT -> [HOTUSDT][sell @ bid][0.002109] -> USDT
# USDT -> [USDTTRY][sell @ bid][18.513] -> TRY
# TRY -> [HOTTRY][buy @ ask][0.03904] -> HOT
#
# Net roundtrip return: 0.010 %
#
#
#
# [2022-09-17 14:24:03.145075]
# REEF -> [REEFUSDT][sell @ bid][0.005753] -> USDT
# USDT -> [USDTTRY][sell @ bid][18.513] -> TRY
# TRY -> [REEFTRY][buy @ ask][0.1065] -> REEF
#
# Net roundtrip return: 0.005 %
#
#
#
# [2022-09-17 14:24:03.145109]
# ROSE -> [ROSETRY][sell @ bid][1.145] -> TRY
# TRY -> [USDTTRY][buy @ ask][18.514] -> USDT
# USDT -> [ROSEUSDT][buy @ ask][0.06184] -> ROSE
#
# Net roundtrip return: 0.008 %
# ERROR:websocket: - goodbye
# ERROR:websocket:error from callback <function on_close at 0x7fcb26ad5050>: on_close() takes 1 positional argument but 3 were given
# True
